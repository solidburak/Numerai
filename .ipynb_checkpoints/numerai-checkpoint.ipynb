# %%
import pandas as pd
import json
import numerapi

napi = numerapi.NumerAPI()
VERSION = "v5.2"

# 2. Read the JSON metadata to get the feature names
with open(f"features.json", "r") as f:
    feature_metadata = json.load(f)

# 3. Extract the "small" feature set (Fixing the official typo here)
small_features = feature_metadata["feature_sets"]["small"]

# We need the 'era' (for time-series validation), our features, and the 'target'
columns_to_read = ["era"] + small_features + ["target"]

print(f"Loading {len(columns_to_read)} columns out of 2000+...")

# 4. Load ONLY the required columns into pandas
training_data = pd.read_parquet(f"train.parquet", columns=columns_to_read)

# Verify the memory footprint
mem_usage = training_data.memory_usage(deep=True).sum() / (1024 ** 2)
print(f"Data loaded successfully! Memory usage: {mem_usage:.2f} MB")
print(training_data.head())
# Out:
# Loading 44 columns out of 2000+...
# Data loaded successfully! Memory usage: 214.76 MB
#                    era  feature_antistrophic_striate_conscriptionist  \
# id
# n0007b5abb0c3a25  0001                                             2
# n003bba8a98662e4  0001                                             2
# n003bee128c2fcfc  0001                                             2
# n0048ac83aff7194  0001                                             2
# n0055a2401ba6480  0001                                             2
#
#                   feature_bicameral_showery_wallaba  \
# id
# n0007b5abb0c3a25                                  2
# n003bba8a98662e4                                  2
# n003bee128c2fcfc                                  2
# n0048ac83aff7194                                  2
# n0055a2401ba6480                                  2
#
#                   feature_bridal_fingered_pensioner  \
# id
# n0007b5abb0c3a25                                  2
# n003bba8a98662e4                                  2
# n003bee128c2fcfc                                  2
# n0048ac83aff7194                                  2
# n0055a2401ba6480                                  2
#
#                   feature_collectivist_flaxen_gueux  \
# id
# n0007b5abb0c3a25                                  2
# n003bba8a98662e4                                  2
# n003bee128c2fcfc                                  2
# n0048ac83aff7194                                  2
# n0055a2401ba6480                                  2
#
#                   feature_concurring_fabled_adapter  \
# id
# n0007b5abb0c3a25                                  2
# n003bba8a98662e4                                  2
# n003bee128c2fcfc                                  2
# n0048ac83aff7194                                  2
# n0055a2401ba6480                                  2
#
#                   feature_crosscut_whilom_ataxy  \
# id
# n0007b5abb0c3a25                              0
# n003bba8a98662e4                              1
# n003bee128c2fcfc                              2
# n0048ac83aff7194                              1
# n0055a2401ba6480                              0
#
#                   feature_departmental_inimitable_sentencer  \
# id
# n0007b5abb0c3a25                                          1
# n003bba8a98662e4                                          4
# n003bee128c2fcfc                                          2
# n0048ac83aff7194                                          4
# n0055a2401ba6480                                          0
#
#                   feature_dialectal_homely_cambodia  \
# id
# n0007b5abb0c3a25                                  2
# n003bba8a98662e4                                  2
# n003bee128c2fcfc                                  2
# n0048ac83aff7194                                  2
# n0055a2401ba6480                                  2
#
#                   feature_donnard_groutier_twinkle  ...  \
# id                                                  ...
# n0007b5abb0c3a25                                 2  ...
# n003bba8a98662e4                                 2  ...
# n003bee128c2fcfc                                 2  ...
# n0048ac83aff7194                                 2  ...
# n0055a2401ba6480                                 2  ...
#
#                   feature_trimeter_soggy_greatest  \
# id
# n0007b5abb0c3a25                                1
# n003bba8a98662e4                                2
# n003bee128c2fcfc                                1
# n0048ac83aff7194                                3
# n0055a2401ba6480                                0
#
#                   feature_unanalyzable_excusable_whirlwind  \
# id
# n0007b5abb0c3a25                                         1
# n003bba8a98662e4                                         0
# n003bee128c2fcfc                                         1
# n0048ac83aff7194                                         4
# n0055a2401ba6480                                         1
#
#                   feature_unbreakable_constraining_hegelianism  \
# id
# n0007b5abb0c3a25                                             3
# n003bba8a98662e4                                             0
# n003bee128c2fcfc                                             0
# n0048ac83aff7194                                             1
# n0055a2401ba6480                                             0
#
#                   feature_unformed_bent_smatch  \
# id
# n0007b5abb0c3a25                             0
# n003bba8a98662e4                             0
# n003bee128c2fcfc                             1
# n0048ac83aff7194                             2
# n0055a2401ba6480                             0
#
#                   feature_unministerial_unextenuated_teleostean  \
# id
# n0007b5abb0c3a25                                              2
# n003bba8a98662e4                                              2
# n003bee128c2fcfc                                              2
# n0048ac83aff7194                                              2
# n0055a2401ba6480                                              2
#
#                   feature_unmodish_zymogenic_rousing  \
# id
# n0007b5abb0c3a25                                   2
# n003bba8a98662e4                                   2
# n003bee128c2fcfc                                   2
# n0048ac83aff7194                                   2
# n0055a2401ba6480                                   2
#
#                   feature_unsystematized_subcardinal_malaysia  \
# id
# n0007b5abb0c3a25                                            3
# n003bba8a98662e4                                            4
# n003bee128c2fcfc                                            0
# n0048ac83aff7194                                            2
# n0055a2401ba6480                                            1
#
#                   feature_willful_sere_chronobiology  \
# id
# n0007b5abb0c3a25                                   3
# n003bba8a98662e4                                   4
# n003bee128c2fcfc                                   3
# n0048ac83aff7194                                   0
# n0055a2401ba6480                                   4
#
#                   feature_zoological_peristomial_scute  target
# id
# n0007b5abb0c3a25                                     2    0.25
# n003bba8a98662e4                                     2    0.50
# n003bee128c2fcfc                                     2    1.00
# n0048ac83aff7194                                     2    0.25
# n0055a2401ba6480                                     2    0.50
#
# [5 rows x 44 columns]

# %%
from sklearn.decomposition import PCA
import numpy as np

# Extract just the feature columns
feature_cols = [c for c in training_data.columns if c.startswith("feature_")]
X_train = training_data[feature_cols]

# Fit Global PCA (extracting the most dominant component)
global_pca = PCA(n_components=1)
global_pca.fit(X_train)

# This is the primary global market vector
global_vector = global_pca.components_[0]

# %%
era_vectors = {}

# Iterate through unique eras
for era in training_data['era'].unique():
    # Isolate data for this specific era
    X_era = training_data[training_data['era'] == era][feature_cols]
    
    # Fit PCA just for this era
    era_pca = PCA(n_components=1)
    era_pca.fit(X_era)
    
    # Store the primary vector for this era
    era_vectors[era] = era_pca.components_[0]

# %%
similarities = {}

for era, era_vector in era_vectors.items():
    # Calculate the dot product
    dot_product = np.dot(global_vector, era_vector)
    
    # We take the absolute value because the sign (+/-) of an eigenvector is arbitrary in PCA
    similarities[era] = np.abs(dot_product)

# Example: Check the alignment of the first era
for era in list(similarities.keys()):
    print(f"Similarity for {era}: {similarities[era]:.4f}")
# Out:
# Similarity for 0001: 0.9186
# Similarity for 0002: 0.9176
# Similarity for 0003: 0.9141
# Similarity for 0004: 0.9231
# Similarity for 0005: 0.9296
# Similarity for 0006: 0.9333
# Similarity for 0007: 0.9399
# Similarity for 0008: 0.9443
# Similarity for 0009: 0.9475
# Similarity for 0010: 0.9484
# Similarity for 0011: 0.9481
# Similarity for 0012: 0.9496
# Similarity for 0013: 0.9481
# Similarity for 0014: 0.9477
# Similarity for 0015: 0.9503
# Similarity for 0016: 0.9512
# Similarity for 0017: 0.9513
# Similarity for 0018: 0.9512
# Similarity for 0019: 0.9510
# Similarity for 0020: 0.9709
# Similarity for 0021: 0.9675
# Similarity for 0022: 0.9648
# Similarity for 0023: 0.9623
# Similarity for 0024: 0.9600
# Similarity for 0025: 0.9503
# Similarity for 0026: 0.9490
# Similarity for 0027: 0.9475
# Similarity for 0028: 0.9412
# Similarity for 0492: 0.9734
# Similarity for 0493: 0.9779
# Similarity for 0494: 0.9811
# Similarity for 0495: 0.9837
# Similarity for 0496: 0.9832
# Similarity for 0497: 0.9835
# Similarity for 0498: 0.9825
# Similarity for 0499: 0.9830
# Similarity for 0500: 0.9835
# Similarity for 0501: 0.9829
# Similarity for 0502: 0.9829
# Similarity for 0503: 0.9830
# Similarity for 0504: 0.9829
# Similarity for 0505: 0.9824
# Similarity for 0506: 0.9839
# Similarity for 0507: 0.9852
# Similarity for 0508: 0.9820
# Similarity for 0509: 0.9794
# Similarity for 0510: 0.9808
# Similarity for 0511: 0.9811
# Similarity for 0512: 0.9833
# Similarity for 0513: 0.9836
# Similarity for 0514: 0.9896
# Similarity for 0515: 0.9899
# Similarity for 0516: 0.9888
# Similarity for 0517: 0.9902
# Similarity for 0518: 0.9889
# Similarity for 0519: 0.9880
# Similarity for 0520: 0.9887
# Similarity for 0521: 0.9885
# Similarity for 0522: 0.9887
# Similarity for 0523: 0.9892
# Similarity for 0524: 0.9870
# Similarity for 0525: 0.9852
# Similarity for 0526: 0.9857
# Similarity for 0527: 0.9877
# Similarity for 0528: 0.9875
# Similarity for 0529: 0.9883
# Similarity for 0530: 0.9877
# Similarity for 0531: 0.9895
# Similarity for 0532: 0.9899
# Similarity for 0533: 0.9894
# Similarity for 0534: 0.9897
# Similarity for 0535: 0.9908
# Similarity for 0536: 0.9904
# Similarity for 0537: 0.9917
# Similarity for 0538: 0.9914
# Similarity for 0539: 0.9927
# Similarity for 0540: 0.9938
# Similarity for 0541: 0.9929
# Similarity for 0542: 0.9918
# Similarity for 0543: 0.9881
# Similarity for 0544: 0.9882
# Similarity for 0545: 0.9888
# Similarity for 0546: 0.9894
# Similarity for 0547: 0.9909
# Similarity for 0548: 0.9925
# Similarity for 0549: 0.9933
# Similarity for 0550: 0.9935
# Similarity for 0551: 0.9922
# Similarity for 0552: 0.9924
# Similarity for 0553: 0.9942
# Similarity for 0554: 0.9932
# Similarity for 0555: 0.9919
# Similarity for 0556: 0.9928
# Similarity for 0557: 0.9923
# Similarity for 0558: 0.9913
# Similarity for 0559: 0.9902
# Similarity for 0560: 0.9887
# Similarity for 0561: 0.9859
# Similarity for 0562: 0.9826
# Similarity for 0563: 0.9819
# Similarity for 0564: 0.9833
# Similarity for 0565: 0.9864
# Similarity for 0566: 0.9911
# Similarity for 0567: 0.9920
# Similarity for 0568: 0.9919
# Similarity for 0569: 0.9929
# Similarity for 0570: 0.9919
# Similarity for 0571: 0.9924
# Similarity for 0572: 0.9925
# Similarity for 0573: 0.9927
# Similarity for 0574: 0.9925

# %%
import matplotlib.pyplot as plt
import seaborn as sns

num_vals = [float(x) for x in similarities.values()]

sns.boxplot(num_vals)
plt.tight_layout()

# %%
from scipy.stats import beta

# Extract just the similarity scores into a numpy array
sim_data = np.array(list(similarities.values()))

# Fit the Beta distribution to our data
# We force loc=0 and scale=1 because our absolute cosine similarities are strictly bounded between 0 and 1
a, b, loc, scale = beta.fit(sim_data, floc=0, fscale=1)

# Find the threshold where only 5% of the distribution falls to the left
# PPF gives us the value at a specific percentile
threshold = beta.ppf(0.05, a, b)

print(f"Fitted Beta parameters: alpha={a:.2f}, beta={b:.2f}")
print(f"Regime Change Threshold (Bottom 5%): {threshold:.4f}")

# Identify the specific eras that are statistically anomalous
anomalous_eras = [era for era, score in similarities.items() if score < threshold]
print(f"Identified {len(anomalous_eras)} anomalous eras.")
# Out:
# Fitted Beta parameters: alpha=51.51, beta=1.46
# Regime Change Threshold (Bottom 5%): 0.9285
# Identified 34 anomalous eras.

# %%
# 1. Isolate the data for the 34 anomalous eras
anomalous_data = training_data[training_data['era'].isin(anomalous_eras)][feature_cols]

# 2. Fit the "Crisis PCA" ONLY on the anomalous data
crisis_pca = PCA(n_components=5) # Extracting the top 5 crisis factors
crisis_pca.fit(anomalous_data)

# 3. Apply (transform) the entire dataset using these crisis components
# We use .transform(), NOT .fit_transform() here!
crisis_features = crisis_pca.transform(training_data[feature_cols])

# 4. Add these new features back to your main DataFrame
for i in range(5):
    training_data[f'crisis_pca_{i}'] = crisis_features[:, i]

# %%
np.sort(training_data['era'].unique(),)[-3:]
# Out:
# array(['0572', '0573', '0574'], dtype=object)

# %%
# Assuming your 'era' column is currently a string like "0001", "0002"
# It is highly recommended to convert it to integers for mathematical filtering!
training_data['era_int'] = training_data['era'].astype(int)

# %%
import numpy as np
import lightgbm as lgb
from scipy.stats import spearmanr
import optuna

# Define the features we are training on (42 small features + 5 crisis components)
all_training_features = small_features + [f'crisis_pca_{i}' for i in range(5)]

def objective(trial):
    # 1. The Menu: Optuna suggests hyperparameters for this specific trial
    params = {
        'max_depth': trial.suggest_int('max_depth', 3, 8),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.1, 1.0),
        'learning_rate': trial.suggest_float('learning_rate', 0.005, 0.05, log=True),
        'n_estimators': 200, # Keeping this moderate to save compute time at home
        'device': 'cuda',
        'random_state': 42
    }
    
    fold_scores = []
    
    # Variables from our expanding window math
    train_start = 1
    train_end_initial = 300
    purge_size = 5
    val_size = 25
    num_folds = int((training_data['era_int'].max() - train_end_initial)/(val_size))
    
    # 2. The Time Machine: 5-Fold Expanding Window
    for i in range(num_folds):
        current_train_end = train_end_initial + (i * val_size)
        purge_end = current_train_end + purge_size
        val_start = purge_end + 1
        val_end = purge_end + val_size
        
        # Filter folds
        train_fold = training_data[(training_data['era_int'] >= train_start) & (training_data['era_int'] <= current_train_end)]
        val_fold = training_data[(training_data['era_int'] >= val_start) & (training_data['era_int'] <= val_end)]
        
        X_train, y_train = train_fold[all_training_features], train_fold['target']
        X_val, y_val = val_fold[all_training_features], val_fold['target']
        
        # 3. Train the Model
        model = lgb.LGBMRegressor(**params)
        model.fit(X_train, y_train)
        
        # 4. Predict on the unseen Validation block
        val_preds = model.predict(X_val)
        
        # 5. Evaluate: Calculate Spearman Rank Correlation
        # spearmanr returns the correlation and the p-value, we only need the correlation [0]
        score = spearmanr(val_preds, y_val)[0] 
        fold_scores.append(score)

    # 6. The Verdict: Calculate Sharpe Ratio
    # Add a tiny number to standard deviation to prevent dividing by zero!
    sharpe = np.mean(fold_scores) / (np.std(fold_scores) + 1e-9)
    
    return sharpe

# %%
# Create a study and tell it we want to MAXIMIZE the Sharpe ratio
study = optuna.create_study(direction='maximize')

# Run 50 trials (guesses)
study.optimize(objective, n_trials=50)

print(f"Best hyperparameters found: {study.best_params}")
# Out:
# [I 2026-03-26 02:45:14,598] A new study created in memory with name: no-name-954e0202-8015-4d88-8f91-8b3dce4112bc
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.045807 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1485
# [LightGBM] [Info] Number of data points in the train set: 1385634, number of used features: 47
# [LightGBM] [Info] Start training from score 0.499946
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.033603 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1485
# [LightGBM] [Info] Number of data points in the train set: 1491992, number of used features: 47
# [LightGBM] [Info] Start training from score 0.499946
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.031374 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1485
# [LightGBM] [Info] Number of data points in the train set: 1602096, number of used features: 47
# [LightGBM] [Info] Start training from score 0.499945
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.035502 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1485
# [LightGBM] [Info] Number of data points in the train set: 1722920, number of used features: 47
# [LightGBM] [Info] Start training from score 0.499946
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.343160 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1485
# [LightGBM] [Info] Number of data points in the train set: 1849160, number of used features: 47
# [LightGBM] [Info] Start training from score 0.499946
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.032952 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1485
# [LightGBM] [Info] Number of data points in the train set: 1979280, number of used features: 47
# [LightGBM] [Info] Start training from score 0.499946
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.055587 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1485
# [LightGBM] [Info] Number of data points in the train set: 2112382, number of used features: 47
# [LightGBM] [Info] Start training from score 0.499947
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.064869 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1485
# [LightGBM] [Info] Number of data points in the train set: 2235724, number of used features: 47
# [LightGBM] [Info] Start training from score 0.499947
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.042037 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1485
# [LightGBM] [Info] Number of data points in the train set: 2359099, number of used features: 47
# [LightGBM] [Info] Start training from score 0.499947
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.040176 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1485
# [LightGBM] [Info] Number of data points in the train set: 2480756, number of used features: 47
# [LightGBM] [Info] Start training from score 0.499947
# [I 2026-03-26 02:50:00,357] Trial 0 finished with value: 5.505465991696465 and parameters: {'max_depth': 8, 'colsample_bytree': 0.5075365869238964, 'learning_rate': 0.0061850843392590605}. Best is trial 0 with value: 5.505465991696465.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.026821 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1485
# [LightGBM] [Info] Number of data points in the train set: 1385634, number of used features: 47
# [LightGBM] [Info] Start training from score 0.499946
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.014154 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1485
# [LightGBM] [Info] Number of data points in the train set: 1491992, number of used features: 47
# [LightGBM] [Info] Start training from score 0.499946
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013404 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1485
# [LightGBM] [Info] Number of data points in the train set: 1602096, number of used features: 47
# [LightGBM] [Info] Start training from score 0.499945
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [I 2026-03-26 02:52:36,692] Trial 1 finished with value: 6.037355345723054 and parameters: {'max_depth': 4, 'colsample_bytree': 0.18310039890259522, 'learning_rate': 0.009073037977428243}. Best is trial 1 with value: 6.037355345723054.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.029441 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1485
# [LightGBM] [Info] Number of data points in the train set: 1385634, number of used features: 47
# [LightGBM] [Info] Start training from score 0.499946
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.018145 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1485
# [LightGBM] [Info] Number of data points in the train set: 1491992, number of used features: 47
# [LightGBM] [Info] Start training from score 0.499946
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.019459 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1485
# [LightGBM] [Info] Number of data points in the train set: 1602096, number of used features: 47
# [LightGBM] [Info] Start training from score 0.499945
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.032734 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1485
# [LightGBM] [Info] Number of data points in the train set: 1722920, number of used features: 47
# [LightGBM] [Info] Start training from score 0.499946
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.025010 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1485
# [LightGBM] [Info] Number of data points in the train set: 1849160, number of used features: 47
# [LightGBM] [Info] Start training from score 0.499946
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.028611 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1485
# [LightGBM] [Info] Number of data points in the train set: 1979280, number of used features: 47
# [LightGBM] [Info] Start training from score 0.499946
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.025266 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1485
# [LightGBM] [Info] Number of data points in the train set: 2112382, number of used features: 47
# [LightGBM] [Info] Start training from score 0.499947
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.026784 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1485
# [LightGBM] [Info] Number of data points in the train set: 2235724, number of used features: 47
# [LightGBM] [Info] Start training from score 0.499947
# [W 2026-03-26 02:54:51,783] Trial 2 failed with parameters: {'max_depth': 5, 'colsample_bytree': 0.28479391345365535, 'learning_rate': 0.023208532033703395} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/home/burak/Documents/Codes/Python/numerai_init_project/.venv/lib/python3.12/site-packages/optuna/study/_optimize.py", line 206, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/tmp/ipykernel_71037/351544214.py", line 44, in objective
#     model.fit(X_train, y_train)
#   File "/home/burak/Documents/Codes/Python/numerai_init_project/.venv/lib/python3.12/site-packages/lightgbm/sklearn.py", line 1398, in fit
#     super().fit(
#   File "/home/burak/Documents/Codes/Python/numerai_init_project/.venv/lib/python3.12/site-packages/lightgbm/sklearn.py", line 1049, in fit
#     self._Booster = train(
#                     ^^^^^^
#   File "/home/burak/Documents/Codes/Python/numerai_init_project/.venv/lib/python3.12/site-packages/lightgbm/engine.py", line 322, in train
#     booster.update(fobj=fobj)
#   File "/home/burak/Documents/Codes/Python/numerai_init_project/.venv/lib/python3.12/site-packages/lightgbm/basic.py", line 4155, in update
#     _LIB.LGBM_BoosterUpdateOneIter(
# KeyboardInterrupt
# [W 2026-03-26 02:54:51,788] Trial 2 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 5
#       2 study = optuna.create_study(direction='maximize')
#       4 # Run 50 trials (guesses)
# ----> 5 study.optimize(objective, n_trials=50)
#       7 print(f"Best hyperparameters found: {study.best_params}")
#
# File ~/Documents/Codes/Python/numerai_init_project/.venv/lib/python3.12/site-packages/optuna/study/study.py:490, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     388 def optimize(
#     389     self,
#     390     func: ObjectiveFuncType,
#    (...)    397     show_progress_bar: bool = False,
#     398 ) -> None:
#     399     """Optimize an objective function.
#     400
#     401     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)    488             If nested invocation of this method occurs.
#     489     """
# --> 490     _optimize(
#     491         study=self,
#     492         func=func,
#     493         n_trials=n_trials,
#     494         timeout=timeout,
#     495         n_jobs=n_jobs,
#     496         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     497         callbacks=callbacks,
#     498         gc_after_trial=gc_after_trial,
#     499         show_progress_bar=show_progress_bar,
#     500     )
#
# File ~/Documents/Codes/Python/numerai_init_project/.venv/lib/python3.12/site-packages/optuna/study/_optimize.py:68, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      66 try:
#      67     if n_jobs == 1:
# ---> 68         _optimize_sequential(
#      69             study,
#      70             func,
#      71             n_trials,
#      72             timeout,
#      73             catch,
#      74             callbacks,
#      75             gc_after_trial,
#      76             reseed_sampler_rng=False,
#      77             time_start=None,
#      78             progress_bar=progress_bar,
#      79         )
#      80     else:
#      81         if n_jobs == -1:
#
# File ~/Documents/Codes/Python/numerai_init_project/.venv/lib/python3.12/site-packages/optuna/study/_optimize.py:165, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     162         break
#     164 try:
# --> 165     frozen_trial_id = _run_trial(study, func, catch)
#     166 finally:
#     167     # The following line mitigates memory problems that can be occurred in some
#     168     # environments (e.g., services that use computing containers such as GitHub Actions).
#     169     # Please refer to the following PR for further details:
#     170     # https://github.com/optuna/optuna/pull/325.
#     171     if gc_after_trial:
#
# File ~/Documents/Codes/Python/numerai_init_project/.venv/lib/python3.12/site-packages/optuna/study/_optimize.py:263, in _run_trial(study, func, catch)
#     256         assert False, "Should not reach."
#     258 if (
#     259     updated_state == TrialState.FAIL
#     260     and func_err is not None
#     261     and not isinstance(func_err, catch)
#     262 ):
# --> 263     raise func_err
#     264 return trial._trial_id
#
# File ~/Documents/Codes/Python/numerai_init_project/.venv/lib/python3.12/site-packages/optuna/study/_optimize.py:206, in _run_trial(study, func, catch)
#     204 with get_heartbeat_thread(trial._trial_id, study._storage):
#     205     try:
# --> 206         value_or_values = func(trial)
#     207     except exceptions.TrialPruned as e:
#     208         # TODO(mamu): Handle multi-objective cases.
#     209         state = TrialState.PRUNED
#
# Cell In[10], line 44, in objective(trial)
#      42 # 3. Train the Model
#      43 model = lgb.LGBMRegressor(**params)
# ---> 44 model.fit(X_train, y_train)
#      46 # 4. Predict on the unseen Validation block
#      47 val_preds = model.predict(X_val)
#
# File ~/Documents/Codes/Python/numerai_init_project/.venv/lib/python3.12/site-packages/lightgbm/sklearn.py:1398, in LGBMRegressor.fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_init_score, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1381 def fit(  # type: ignore[override]
#    1382     self,
#    1383     X: _LGBM_ScikitMatrixLike,
#    (...)   1395     init_model: Optional[Union[str, Path, Booster, LGBMModel]] = None,
#    1396 ) -> "LGBMRegressor":
#    1397     """Docstring is inherited from the LGBMModel."""
# -> 1398     super().fit(
#    1399         X,
#    1400         y,
#    1401         sample_weight=sample_weight,
#    1402         init_score=init_score,
#    1403         eval_set=eval_set,
#    1404         eval_names=eval_names,
#    1405         eval_sample_weight=eval_sample_weight,
#    1406         eval_init_score=eval_init_score,
#    1407         eval_metric=eval_metric,
#    1408         feature_name=feature_name,
#    1409         categorical_feature=categorical_feature,
#    1410         callbacks=callbacks,
#    1411         init_model=init_model,
#    1412     )
#    1413     return self
#
# File ~/Documents/Codes/Python/numerai_init_project/.venv/lib/python3.12/site-packages/lightgbm/sklearn.py:1049, in LGBMModel.fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1046 evals_result: _EvalResultDict = {}
#    1047 callbacks.append(record_evaluation(evals_result))
# -> 1049 self._Booster = train(
#    1050     params=params,
#    1051     train_set=train_set,
#    1052     num_boost_round=self.n_estimators,
#    1053     valid_sets=valid_sets,
#    1054     valid_names=eval_names,
#    1055     feval=eval_metrics_callable,  # type: ignore[arg-type]
#    1056     init_model=init_model,
#    1057     callbacks=callbacks,
#    1058 )
#    1060 # This populates the property self.n_features_, the number of features in the fitted model,
#    1061 # and so should only be set after fitting.
#    1062 #
#    1063 # The related property self._n_features_in, which populates self.n_features_in_,
#    1064 # is set BEFORE fitting.
#    1065 self._n_features = self._Booster.num_feature()
#
# File ~/Documents/Codes/Python/numerai_init_project/.venv/lib/python3.12/site-packages/lightgbm/engine.py:322, in train(params, train_set, num_boost_round, valid_sets, valid_names, feval, init_model, keep_training_booster, callbacks)
#     310 for cb in callbacks_before_iter:
#     311     cb(
#     312         callback.CallbackEnv(
#     313             model=booster,
#    (...)    319         )
#     320     )
# --> 322 booster.update(fobj=fobj)
#     324 evaluation_result_list: List[_LGBM_BoosterEvalMethodResultType] = []
#     325 # check evaluation result.
#
# File ~/Documents/Codes/Python/numerai_init_project/.venv/lib/python3.12/site-packages/lightgbm/basic.py:4155, in Booster.update(self, train_set, fobj)
#    4152 if self.__set_objective_to_none:
#    4153     raise LightGBMError("Cannot update due to null objective function.")
#    4154 _safe_call(
# -> 4155     _LIB.LGBM_BoosterUpdateOneIter(
#    4156         self._handle,
#    4157         ctypes.byref(is_finished),
#    4158     )
#    4159 )
#    4160 self.__is_predicted_cur_iter = [False for _ in range(self.__num_dataset)]
#    4161 return is_finished.value == 1
#
# KeyboardInterrupt:
